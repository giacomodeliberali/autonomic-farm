# %%
# Dependencies
import os
import pandas as pd
import matplotlib.pyplot as plt

# Read the data set
root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
df = pd.read_csv(os.path.join(root, 'csv', 'srv3.csv'))
# window,expected_throughput,actual_throughput,nw,average,average_treshold,trend,trend_treshold

# %%
plt.plot(df["tasks"], df["actual_throughput"])
#plt.plot(df["tasks"], df["nw"], color='orange')
plt.axhline(y=df["expected_throughput"][0], color='r', linestyle=':')
plt.xlabel("tasks")
plt.ylabel("throughput (task per ms)")
plt.title("Actual throughput")
plt.show()

# %%
plt.plot(df["tasks"], df["nw"])
plt.xlabel("tasks")
plt.ylabel("# workers")
plt.show()

# %%
# Ok local default
#define MONITOR_NOTIFICATION_INTERVAL 10
#define STRATEGY_WINDOW_SIZE 2
#define TREND_THRESHOLD  1/20
#define AVERAGE_THRESHOLD 1/10

# Mhmm server constant
#define MONITOR_NOTIFICATION_INTERVAL 10
#define STRATEGY_WINDOW_SIZE 2
#define TREND_THRESHOLD  1/20
#define AVERAGE_THRESHOLD 1/10
