# %%
# Dependencies
import os
import pandas as pd
import matplotlib.pyplot as plt

# Read the data set
root = os.path.abspath(os.path.join(os.getcwd(), os.pardir))

def print_csv(name):
    df = pd.read_csv(os.path.join(root, 'csv', name))
    f, axs = plt.subplots(2,2,figsize=(20,5))
    plt.subplot(1, 2, 1)
    plt.plot(df["tasks"], df["actual_throughput"])
    #plt.plot(df["tasks"], df["nw"], color='orange')
    plt.axhline(y=df["expected_throughput"][0], color='r', linestyle=':')
    #plt.axvline(x=30000, color='green', linestyle=':')
    plt.xlabel("tasks")
    plt.ylabel("throughput")
    plt.title("Actual throughput")

    plt.subplot(1, 2, 2)
    plt.plot(df["tasks"], df["nw"])
    plt.xlabel("tasks")
    plt.ylabel("workers")
    plt.title("Workers count")


    #plt.tight_layout()
    plt.show()

# %% [markdown]
# # Default

# %%
for i in range(1,6):
    print_csv(f'srv-default-{i}.csv')

# %% [markdown]
# # Constant

# %%
for i in range(1,6):
    print_csv(f'srv-constant-{i}.csv')

# %% [markdown]
# # Reverse default

# %%
for i in range(1,6):
    print_csv(f'srv-reverse-default-{i}.csv')

# %% [markdown]
# # Low-high

# %%
for i in range(1,6):
    print_csv(f'srv-lowhigh-{i}.csv')

# %% [markdown]
# # High-low

# %%
for i in range(1,6):
    print_csv(f'srv-highlow-{i}.csv')
